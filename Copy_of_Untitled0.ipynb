# %% [markdown]
# <a href="https://colab.research.google.com/github/Safiyabegum52/Simple-registration-form-/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/ttd task/titanic.txt")

# %%
import os

directory_path = "/content/drive/MyDrive/ttd task/"
print(f"Contents of '{directory_path}':")
for item in os.listdir(directory_path):
    print(item)
# Out:
# Contents of '/content/drive/MyDrive/ttd task/':
# Ttdtask
# titanic.txt
# Untitled0.ipynb

# %%
df=pd.read_csv("/content/drive/MyDrive/intern/economic-survey-of-manufacturing-december-2025-quarter.csv")

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0          MFGQ.SFA1CA  1992.12    2493.370        NaN      F  Dollars
# 1          MFGQ.SFA1CA  1993.03    3209.200        NaN      F  Dollars
# 2          MFGQ.SFA1CA  1993.06    2780.170        NaN      F  Dollars
# 3          MFGQ.SFA1CA  1993.09    1933.010        NaN      F  Dollars
# 4          MFGQ.SFA1CA  1993.12    2692.920        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 30766      MFGQ.SFZ5KA  2024.12   10643.807        NaN      F  Dollars
# 30767      MFGQ.SFZ5KA  2025.03   10863.217        NaN      F  Dollars
# 30768      MFGQ.SFZ5KA  2025.06    9086.747        NaN      F  Dollars
# 30769      MFGQ.SFZ5KA  2025.09    9448.195        NaN      R  Dollars
# 30770      MFGQ.SFZ5KA  2025.12   10449.981        NaN      F  Dollars
#
#        Magnitude                                Subject  \
# 0              6  Manufacturing Survey (ANZSIC06) - MFG
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0      MFGQ.SFA1CA  1992.12     2493.37        NaN      F  Dollars          6
# 1      MFGQ.SFA1CA  1993.03     3209.20        NaN      F  Dollars          6
# 2      MFGQ.SFA1CA  1993.06     2780.17        NaN      F  Dollars          6
# 3      MFGQ.SFA1CA  1993.09     1933.01        NaN      F  Dollars          6
# 4      MFGQ.SFA1CA  1993.12     2692.92        NaN      F  Dollars          6
#
#                                  Subject  \
# 0  Manufacturing Survey (ANZSIC06) - MFG
# 1  Manufacturing Survey (ANZSIC06) - MFG
# 2  Manufacturing Survey (ANZSIC06) - MFG
# 3  Manufacturing Survey (ANZSIC06) - MFG
# 4  Manufacturing Survey (ANZSIC06) - MFG
#
#                                                Group  \
# 0  Industry by variable - Subannual Financial Col...
# 1  Industry by variable - Subannual Financial Col...
# 2  Industry by variable - Subannual Financial Col...
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 30766      MFGQ.SFZ5KA  2024.12   10643.807        NaN      F  Dollars
# 30767      MFGQ.SFZ5KA  2025.03   10863.217        NaN      F  Dollars
# 30768      MFGQ.SFZ5KA  2025.06    9086.747        NaN      F  Dollars
# 30769      MFGQ.SFZ5KA  2025.09    9448.195        NaN      R  Dollars
# 30770      MFGQ.SFZ5KA  2025.12   10449.981        NaN      F  Dollars
#
#        Magnitude                                Subject  \
# 30766          6  Manufacturing Survey (ANZSIC06) - MFG
# 30767          6  Manufacturing Survey (ANZSIC06) - MFG
# 30768          6  Manufacturing Survey (ANZSIC06) - MFG
# 30769          6  Manufacturing Survey (ANZSIC06) - MFG
# 30770          6  Manufacturing Survey (ANZSIC06) - MFG
#
#                                                    Group     Series_title_1  \
# 30766  Industry by variable - Subannual Financial Col...  All manufacturing
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30771 entries, 0 to 30770
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  30771 non-null  object
#  1   Period            30771 non-null  float64
#  2   Data_value        30022 non-null  float64
#  3   Suppressed        2 non-null      object
#  4   STATUS            30771 non-null  object
#  5   UNITS             30771 non-null  object
#  6   Magnitude         30771 non-null  int64
#  7   Subject           30771 non-null  object
#  8   Group             30771 non-null  object
#  9   Series_title_1    30771 non-null  object
#  10  Series_title_2    30771 non-null  object
#  11  Series_title_3    30771 non-null  object
#  12  Series_title_4    30771 non-null  object
#  13  Series_title_5    1494 non-null   object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 3.3+ MB

# %%
df.describe()
# Out:
#              Period    Data_value     Magnitude
# count  30771.000000  30022.000000  30771.000000
# mean    2009.332826   2997.387560      5.708687
# std        9.387814   5307.566663      1.289601
# min     1992.120000    -26.000000      0.000000
# 25%     2001.090000    380.111000      6.000000
# 50%     2009.120000    981.310000      6.000000
# 75%     2017.120000   2224.295750      6.000000
# max     2025.120000  36815.633000      6.000000

# %%
df.shape
# Out:
# (30771, 14)

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4       object
# Series_title_5       object
# dtype: object

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.groupby('Subject')

# %%
# To fix this error, you need to provide another DataFrame to merge with.
# For example, if you have a DataFrame named 'df2':
# df.merge(df2)
# df.merge(df2, on='common_column')

# As no other DataFrame is defined, this line will still produce an error.
# You can create a dummy DataFrame to see how it works:
# df2 = pd.DataFrame({'common_column': [1, 2, 3], 'new_data': ['A', 'B', 'C']})
# df.merge(df2, left_on='Series_reference', right_on='common_column') # Example using an existing column from df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2227/2281845631.py in <cell line: 0>()
# ----> 1 df.merge()
#
# TypeError: DataFrame.merge() missing 1 required positional argument: 'right'

# %%
df.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2227/1685560713.py in <cell line: 0>()
# ----> 1 df.sort_values()
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
df = df.drop('Period', axis=1)
display(df.head())
# Out:
#   Series_reference  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0      MFGQ.SFA1CA     2493.37        NaN      F  Dollars          6
# 1      MFGQ.SFA1CA     3209.20        NaN      F  Dollars          6
# 2      MFGQ.SFA1CA     2780.17        NaN      F  Dollars          6
# 3      MFGQ.SFA1CA     1933.01        NaN      F  Dollars          6
# 4      MFGQ.SFA1CA     2692.92        NaN      F  Dollars          6
#
#                                  Subject  \
# 0  Manufacturing Survey (ANZSIC06) - MFG
# 1  Manufacturing Survey (ANZSIC06) - MFG
# 2  Manufacturing Survey (ANZSIC06) - MFG
# 3  Manufacturing Survey (ANZSIC06) - MFG
# 4  Manufacturing Survey (ANZSIC06) - MFG
#
#                                                Group  \
# 0  Industry by variable - Subannual Financial Col...
# 1  Industry by variable - Subannual Financial Col...
# 2  Industry by variable - Subannual Financial Col...
# 3  Industry by variable - Subannual Financial Col...
# ...

# %%
print(df.groupby)
# Out:
# <bound method DataFrame.groupby of       Series_reference  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0          MFGQ.SFA1CA    2493.370        NaN      F  Dollars          6
# 1          MFGQ.SFA1CA    3209.200        NaN      F  Dollars          6
# 2          MFGQ.SFA1CA    2780.170        NaN      F  Dollars          6
# 3          MFGQ.SFA1CA    1933.010        NaN      F  Dollars          6
# 4          MFGQ.SFA1CA    2692.920        NaN      F  Dollars          6
# ...                ...         ...        ...    ...      ...        ...
# 30766      MFGQ.SFZ5KA   10643.807        NaN      F  Dollars          6
# 30767      MFGQ.SFZ5KA   10863.217        NaN      F  Dollars          6
# 30768      MFGQ.SFZ5KA    9086.747        NaN      F  Dollars          6
# 30769      MFGQ.SFZ5KA    9448.195        NaN      R  Dollars          6
# 30770      MFGQ.SFZ5KA   10449.981        NaN      F  Dollars          6
#
#                                      Subject  \
# ...

# %%
print(df.merge)
# Out:
# <bound method DataFrame.merge of       Series_reference  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0          MFGQ.SFA1CA    2493.370        NaN      F  Dollars          6
# 1          MFGQ.SFA1CA    3209.200        NaN      F  Dollars          6
# 2          MFGQ.SFA1CA    2780.170        NaN      F  Dollars          6
# 3          MFGQ.SFA1CA    1933.010        NaN      F  Dollars          6
# 4          MFGQ.SFA1CA    2692.920        NaN      F  Dollars          6
# ...                ...         ...        ...    ...      ...        ...
# 30766      MFGQ.SFZ5KA   10643.807        NaN      F  Dollars          6
# 30767      MFGQ.SFZ5KA   10863.217        NaN      F  Dollars          6
# 30768      MFGQ.SFZ5KA    9086.747        NaN      F  Dollars          6
# 30769      MFGQ.SFZ5KA    9448.195        NaN      R  Dollars          6
# 30770      MFGQ.SFZ5KA   10449.981        NaN      F  Dollars          6
#
#                                      Subject  \
# ...

# %%
print(df.sort_values)
# Out:
# <bound method DataFrame.sort_values of       Series_reference  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0          MFGQ.SFA1CA    2493.370        NaN      F  Dollars          6
# 1          MFGQ.SFA1CA    3209.200        NaN      F  Dollars          6
# 2          MFGQ.SFA1CA    2780.170        NaN      F  Dollars          6
# 3          MFGQ.SFA1CA    1933.010        NaN      F  Dollars          6
# 4          MFGQ.SFA1CA    2692.920        NaN      F  Dollars          6
# ...                ...         ...        ...    ...      ...        ...
# 30766      MFGQ.SFZ5KA   10643.807        NaN      F  Dollars          6
# 30767      MFGQ.SFZ5KA   10863.217        NaN      F  Dollars          6
# 30768      MFGQ.SFZ5KA    9086.747        NaN      F  Dollars          6
# 30769      MFGQ.SFZ5KA    9448.195        NaN      R  Dollars          6
# 30770      MFGQ.SFZ5KA   10449.981        NaN      F  Dollars          6
#
#                                      Subject  \
# ...

# %%
print(dir(df))
# Out:
# ['Data_value', 'Group', 'Magnitude', 'STATUS', 'Series_reference', 'Series_title_1', 'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5', 'Subject', 'Suppressed', 'T', 'UNITS', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__mo
# ...

# %%
print(df.isnull().sum())
# Out:
# Series_reference        0
# Data_value            749
# Suppressed          30769
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4          0
# Series_title_5      29277
# dtype: int64

# %%
df=df.dropna()
print(df.isnull().sum())
# Out:
# Series_reference    0
# Data_value          0
# Suppressed          0
# STATUS              0
# UNITS               0
# Magnitude           0
# Subject             0
# Group               0
# Series_title_1      0
# Series_title_2      0
# Series_title_3      0
# Series_title_4      0
# Series_title_5      0
# dtype: int64
